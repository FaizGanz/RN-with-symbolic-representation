# %% [markdown]
# ## Part 1: Model Explanation
#
# Simple relational inferences have proved challenging through simple black-box architectures such as MLPs, CNNs, RNNs or a combination of them. A solution to this problem is the implementation of Relational Network modules throughout the selected base architecture.
#
# A Relational network is a neural network module that is used to model relational reasoning. The idea behind Relational networks is to use general-purpose components (MLPs) so that we can capture the patterns of relational properties and use them to augment the network architecture by modulating the upstream representations (feature maps).
#
# RN Module:
#
# $RN(O) = f_ϕ(\sum_{i,j} g_\theta (o_i, o_j))$
#
# The input to the Rn module is the set object $O = \{o_1, o_2, ..., o_n\}$, where $o_i ∈ \mathbb{R}^m$. The functions $f_\phi$ and $g_\theta$ are simple MLPs with parameters $\phi$ and $\theta$. For each pair of objects $(o_i, o_j)$ the function $g_\theta$ is tasked with inferring their relationship in an order invariant manner. Because the module is made with general purpose components it is end-to-end differentiable. There is no specific requirement for what an object can be, hence relatively unstructured inputs such as CNN or LSTM embeddings can be used as objects.
#
# In reality however, the RN quesiton dependent. Hence the correct formulation is $a = f_ϕ(\sum_{i,j} g_\theta (o_i, o_j, q))$.
#
# For the Sort-of-CLEVR dataset, the model used does not contain an LSTM portion. The questions are encoded as binary strings embeddings of fixed size which are passed directly to the RN module in combination with the object representations.
#
# The model consists of four convolution layers with 32, 64, 128, and 256 kernels coupled with ReLU activation functions and batch-normalization. The RN module is made up by a four layer MLP with 2000 neurons per layer for the function $g_\theta$ and a four layer MLP with 2000, 1000, 500, and 100 neurons respectively for the function $f_\phi$.
#
# The model is topped with a final classification layer and trained using CE loss and an Adam optimizer with learning rate of $1e-4$.

# %% [markdown]
# ## Part 2: Model Implementation

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

from __future__ import print_function
import os
import pickle
import random
import numpy as np
import csv

import torch
from torch.utils.tensorboard import SummaryWriter

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# %cd '/content/gdrive/MyDrive/ai/finalpj'
# Out:
# /content/gdrive/MyDrive/ai/finalpj

# %% [markdown]
# ### Sub-Models

# %%
class ConvInputModel(nn.Module):
    def __init__(self):
        super(ConvInputModel, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 32, 3, stride=2, padding=1)
        self.batchNorm1 = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3, stride=2, padding=1)
        self.batchNorm2 = nn.BatchNorm2d(64)
        self.conv3 = nn.Conv2d(64, 128, 3, stride=2, padding=1)
        self.batchNorm3 = nn.BatchNorm2d(128)
        self.conv4 = nn.Conv2d(128, 256, 3, stride=2, padding=1)
        self.batchNorm4 = nn.BatchNorm2d(256)
        
    def forward(self, img):
        """convolution"""
        x = self.conv1(img)
        x = F.relu(x)
        x = self.batchNorm1(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.batchNorm2(x)
        x = self.conv3(x)
        x = F.relu(x)
        x = self.batchNorm3(x)
        x = self.conv4(x)
        x = F.relu(x)
        x = self.batchNorm4(x)
        return x

# %%
class FCOutputModel(nn.Module):
    def __init__(self):
        super(FCOutputModel, self).__init__()

        self.fc2 = nn.Linear(100, 100)
        self.fc3 = nn.Linear(100, 10)

    def forward(self, x):
        x = self.fc2(x)
        x = F.relu(x)
        x = F.dropout(x)
        x = self.fc3(x)
        return F.log_softmax(x, dim=1)

# %%
class BasicModel(nn.Module):
    def __init__(self, name, **kwargs):
        super(BasicModel, self).__init__()
        self.name=name

    def train_(self, input_img, input_qst, label):
        self.optimizer.zero_grad()
        output = self(input_img, input_qst)
        loss = F.nll_loss(output, label)
        loss.backward()
        self.optimizer.step()
        pred = output.data.max(1)[1]
        correct = pred.eq(label.data).cpu().sum()
        accuracy = correct * 100. / len(label)
        return accuracy, loss
        
    def test_(self, input_img, input_qst, label):
        output = self(input_img, input_qst)
        loss = F.nll_loss(output, label)
        pred = output.data.max(1)[1]
        correct = pred.eq(label.data).cpu().sum()
        accuracy = correct * 100. / len(label)
        return accuracy, loss

    def save_model(self, epoch):
        torch.save(self.state_dict(), 'model/epoch_{}_{:02d}.pth'.format(self.name, epoch))

# %% [markdown]
# ### RN for Images

# %%
class RN(BasicModel):
    def __init__(self, **kwargs):
        super(RN, self).__init__('RN', **kwargs)
        
        self.conv = ConvInputModel()
        
        self.relation_type = kwargs['relation_type']
        
        if self.relation_type == 'ternary':
            ##(number of filters per object+coordinate of object)*3+question vector
            self.g_fc1 = nn.Linear((256+2)*3+18, 2000)
        else:
            ##(number of filters per object+coordinate of object)*2+question vector
            self.g_fc1 = nn.Linear((256+2)*2+18, 2000)

        self.g_fc2 = nn.Linear(2000, 2000)
        self.g_fc3 = nn.Linear(2000, 2000)
        self.g_fc4 = nn.Linear(2000, 2000)

        self.f_fc1 = nn.Linear(2000, 2000)
        self.f_fc2 = nn.Linear(2000, 1000)
        self.f_fc3 = nn.Linear(1000, 500)
        self.f_fc4 = nn.Linear(500, 100)

        self.coord_oi = torch.FloatTensor(kwargs['batch_size'], 2)
        self.coord_oj = torch.FloatTensor(kwargs['batch_size'], 2)
        if kwargs['cuda']:
            self.coord_oi = self.coord_oi.cuda()
            self.coord_oj = self.coord_oj.cuda()
        # self.coord_oi = Variable(self.coord_oi)
        # self.coord_oj = Variable(self.coord_oj)

        # prepare coord tensor
        def cvt_coord(i):
            return [(i/5-2)/2., (i%5-2)/2.]
        
        self.coord_tensor = torch.FloatTensor(kwargs['batch_size'], 25, 2)
        if kwargs['cuda']:
            self.coord_tensor = self.coord_tensor.cuda()
        # self.coord_tensor = Variable(self.coord_tensor)
        np_coord_tensor = np.zeros((kwargs['batch_size'], 25, 2))
        for i in range(25):
            np_coord_tensor[:,i,:] = np.array( cvt_coord(i) )
        self.coord_tensor.data.copy_(torch.from_numpy(np_coord_tensor))

        self.fcout = FCOutputModel()
        
        self.optimizer = optim.Adam(self.parameters(), lr=kwargs['lr'])


    def forward(self, img, qst):
        x = self.conv(img) ## x = (64 x 256 x 5 x 5)
        """g"""
        mb = x.size()[0]
        n_channels = x.size()[1]
        d = x.size()[2]
        
        x_flat = x.view(mb, n_channels, d * d).permute(0, 2, 1) # (64 x 25 x 256)
        x_flat = torch.cat([x_flat, self.coord_tensor], 2) # (64 x 25 x 256+2)

        # add question everywhere
        qst = torch.unsqueeze(qst, 1) # (64 x 1 x 18)
        qst = qst.repeat(1, 25, 1) # (64 x 25 x 18)
        qst = torch.unsqueeze(qst, 2) # (64 x 25 x 1 x 18)
        
        # cast all pairs against each other
        x_i = torch.unsqueeze(x_flat, 1)  # (64 x 1 x 25 x 258)
        x_i = x_i.repeat(1, 25, 1, 1)  # (64 x 25 x 25 x 258)
        x_j = torch.unsqueeze(x_flat, 2)  # (64 x 25 x 1 x 258)
        x_j = torch.cat([x_j, qst], 3) # (64 x 25 x 1 x 258+18)
        x_j = x_j.repeat(1, 1, 25, 1) # (64 x 25 x 25 x 276)
        
        # concatenate all together
        x_full = torch.cat([x_i,x_j],3) # (64 x 25 x 25 x 258+276)
    
        # reshape for passing through network
        x_ = x_full.view(mb * (d * d) * (d * d), 534)  # (64 x 25 x 25 x 534) = (40000, 534)
         
        """g"""
        x_ = self.g_fc1(x_) # (40000, 2000)
        x_ = F.relu(x_)
        x_ = self.g_fc2(x_) # (40000, 2000)
        x_ = F.relu(x_)
        x_ = self.g_fc3(x_) # (40000, 2000)
        x_ = F.relu(x_)
        x_ = self.g_fc4(x_) # (40000, 2000)
        x_ = F.relu(x_)

        # reshape again and sum
        if self.relation_type == 'ternary':
            x_g = x_.view(mb, (d * d) * (d * d) * (d * d), 2000)
        else:
            x_g = x_.view(mb, (d * d) * (d * d), 2000)
        x_g = x_g.sum(1).squeeze()

        """f"""
        x_f = self.f_fc1(x_g) # (64, 2000)
        x_f = F.relu(x_f)
        x_f = self.f_fc2(x_f) # (64, 1000)
        x_f = F.relu(x_f)
        x_f = self.f_fc3(x_f) # (64, 500)
        x_f = F.relu(x_f)
        x_f = self.f_fc4(x_f) # (64, 100)
        x_f = F.relu(x_f)
        
        return self.fcout(x_f)

# %% [markdown]
# ### RN for State Description

# %%
class RN_State(BasicModel):
    def __init__(self, **kwargs):
        super(RN_State, self).__init__('RN_State', **kwargs)
        
        self.relation_type = kwargs['relation_type']
        
        if self.relation_type == 'ternary':
            ##(number of filters per object+coordinate of object)*3+question vector
            self.g_fc1 = nn.Linear((4)*3+18, 2000)
        else:
            ##(number of filters per object+coordinate of object)*2+question vector
            self.g_fc1 = nn.Linear((4)*2+18, 2000)

        self.g_fc2 = nn.Linear(2000, 2000)
        self.g_fc3 = nn.Linear(2000, 2000)
        self.g_fc4 = nn.Linear(2000, 2000)

        self.f_fc1 = nn.Linear(2000, 2000)
        self.f_fc2 = nn.Linear(2000, 1000)
        self.f_fc3 = nn.Linear(1000, 500)
        self.f_fc4 = nn.Linear(500, 100)

        self.fcout = FCOutputModel()
        
        self.optimizer = optim.Adam(self.parameters(), lr=kwargs['lr'])


    def forward(self, img, qst):

        x = img
        # print(x.shape, qst.shape)
        # raise NotImplementedError

        """g"""
        mb = x.size()[0]
        n_obj = x.size()[1]
        feat_dim = x.size()[2]
        qst_len = qst.size()[1]
        
        # add question everywhere
        qst = torch.unsqueeze(qst, 1) # (batch_size, 1, qst_len)
        qst = qst.repeat(1, n_obj, 1) # (batch_size, n_objs, qst_len)
        qst = torch.unsqueeze(qst, 2) # (batch_size, n_objs, 1, qst_len)
        
        # cast all pairs against each other
        x_i = x.unsqueeze(dim=1) # (batch_size, 1, n_objs, feat_dim)
        x_i = x_i.repeat(1, n_obj, 1, 1) # (batch_size, n_objs, n_objs, feat_dim)
        x_j = x.unsqueeze(dim=2) # (batch_size, n_objs, 1, feat_dim)
        x_j = torch.cat([x_j, qst], 3) # (batch_size, n_objs, 1, feat_dim + qst_len)
        x_j = x_j.repeat(1, 1, n_obj, 1) # (batch_size, n_objs, n_objs, feat_dim + qst_len)
        
        # concatenate all together
        x_full = torch.cat([x_i,x_j],3) # (batch_size, n_objs, n_objs, 2 * feat_dim + qst_len)
    
        # reshape for passing through network
        x_ = x_full.view(mb * n_obj * n_obj, 2 * feat_dim + qst_len)  # (64 x 25 x 25 x 534) = (40000, 534)
         
        """g"""
        x_ = self.g_fc1(x_) # (40000, 2000)
        x_ = F.relu(x_)
        x_ = self.g_fc2(x_) # (40000, 2000)
        x_ = F.relu(x_)
        x_ = self.g_fc3(x_) # (40000, 2000)
        x_ = F.relu(x_)
        x_ = self.g_fc4(x_) # (40000, 2000)
        x_ = F.relu(x_)

        # reshape again and sum
        if self.relation_type == 'ternary':
            x_g = x_.view(mb, n_obj * n_obj * n_obj, 2000)
        else:
            x_g = x_.view(mb, n_obj * n_obj, 2000)
        x_g = x_g.sum(1).squeeze()

        """f"""
        x_f = self.f_fc1(x_g) # (64, 2000)
        x_f = F.relu(x_f)
        x_f = self.f_fc2(x_f) # (64, 1000)
        x_f = F.relu(x_f)
        x_f = self.f_fc3(x_f) # (64, 500)
        x_f = F.relu(x_f)
        x_f = self.f_fc4(x_f) # (64, 100)
        x_f = F.relu(x_f)
        
        return self.fcout(x_f)

# %% [markdown]
# ### Functions

# %%
summary_writer = SummaryWriter()

# %%
def tensor_data(data, i):
    img = torch.from_numpy(np.asarray(data[0][bs*i:bs*(i+1)]))
    qst = torch.from_numpy(np.asarray(data[1][bs*i:bs*(i+1)]))
    ans = torch.from_numpy(np.asarray(data[2][bs*i:bs*(i+1)]))
    state = torch.from_numpy(np.asarray(data[3][bs*i:bs*(i+1)]))

    input_img.data.resize_(img.size()).copy_(img)
    input_qst.data.resize_(qst.size()).copy_(qst)
    label.data.resize_(ans.size()).copy_(ans)
    input_state.data.resize_(state.size()).copy_(state)

# %%
def cvt_data_axis(data):
    img = [e[0] for e in data]
    qst = [e[1] for e in data]
    ans = [e[2] for e in data]
    state = [e[3] for e in data]
    return (img,qst,ans,state)

# %%
def train(epoch, ternary, rel, norel, state=False):
    model.train()

    if not len(rel[0]) == len(norel[0]):
        print('Not equal length for relation dataset and non-relation dataset.')
        return
    
    random.shuffle(ternary)
    random.shuffle(rel)
    random.shuffle(norel)

    ternary = cvt_data_axis(ternary)
    rel = cvt_data_axis(rel)
    norel = cvt_data_axis(norel)

    acc_ternary = []
    acc_rels = []
    acc_norels = []

    l_ternary = []
    l_binary = []
    l_unary = []


    for batch_idx in range(len(rel[0]) // bs):
        tensor_data(ternary, batch_idx)
        if state:
            accuracy_ternary, loss_ternary = model.train_(input_state, input_qst, label)
        else:
            accuracy_ternary, loss_ternary = model.train_(input_img, input_qst, label)
        acc_ternary.append(accuracy_ternary.item())
        l_ternary.append(loss_ternary.item())

        tensor_data(rel, batch_idx)
        if state:
            accuracy_rel, loss_binary = model.train_(input_state, input_qst, label)
        else:
            accuracy_rel, loss_binary = model.train_(input_img, input_qst, label)
        acc_rels.append(accuracy_rel.item())
        l_binary.append(loss_binary.item())

        tensor_data(norel, batch_idx)
        if state:
            accuracy_norel, loss_unary = model.train_(input_state, input_qst, label)
        else:
            accuracy_norel, loss_unary = model.train_(input_img, input_qst, label)
        acc_norels.append(accuracy_norel.item())
        l_unary.append(loss_unary.item())

        if batch_idx % log_interval == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)] '
                  'Ternary accuracy: {:.0f}% | Relations accuracy: {:.0f}% | Non-relations accuracy: {:.0f}%'.format(
                   epoch,
                   batch_idx * bs * 2,
                   len(rel[0]) * 2,
                   100. * batch_idx * bs / len(rel[0]),
                   accuracy_ternary,
                   accuracy_rel,
                   accuracy_norel))
        
    avg_acc_ternary = sum(acc_ternary) / len(acc_ternary)
    avg_acc_binary = sum(acc_rels) / len(acc_rels)
    avg_acc_unary = sum(acc_norels) / len(acc_norels)

    summary_writer.add_scalars('Accuracy/train', {
        'ternary': avg_acc_ternary,
        'binary': avg_acc_binary,
        'unary': avg_acc_unary
    }, epoch)

    avg_loss_ternary = sum(l_ternary) / len(l_ternary)
    avg_loss_binary = sum(l_binary) / len(l_binary)
    avg_loss_unary = sum(l_unary) / len(l_unary)

    summary_writer.add_scalars('Loss/train', {
        'ternary': avg_loss_ternary,
        'binary': avg_loss_binary,
        'unary': avg_loss_unary
    }, epoch)

    # return average accuracy
    return avg_acc_ternary, avg_acc_binary, avg_acc_unary

# %%
def test(epoch, ternary, rel, norel, state=False):
    model.eval()
    if not len(rel[0]) == len(norel[0]):
        print('Not equal length for relation dataset and non-relation dataset.')
        return
    
    ternary = cvt_data_axis(ternary)
    rel = cvt_data_axis(rel)
    norel = cvt_data_axis(norel)

    accuracy_ternary = []
    accuracy_rels = []
    accuracy_norels = []

    loss_ternary = []
    loss_binary = []
    loss_unary = []

    for batch_idx in range(len(rel[0]) // bs):
        tensor_data(ternary, batch_idx)
        if state:
            acc_ter, l_ter = model.test_(input_state, input_qst, label)
        else:
            acc_ter, l_ter = model.test_(input_img, input_qst, label)
        accuracy_ternary.append(acc_ter.item())
        loss_ternary.append(l_ter.item())

        tensor_data(rel, batch_idx)
        if state:
            acc_bin, l_bin = model.test_(input_state, input_qst, label)
        else:
            acc_bin, l_bin = model.test_(input_img, input_qst, label)
        accuracy_rels.append(acc_bin.item())
        loss_binary.append(l_bin.item())

        tensor_data(norel, batch_idx)
        if state:
            acc_un, l_un = model.test_(input_state, input_qst, label)
        else:
            acc_un, l_un = model.test_(input_img, input_qst, label)
        accuracy_norels.append(acc_un.item())
        loss_unary.append(l_un.item())

    accuracy_ternary = sum(accuracy_ternary) / len(accuracy_ternary)
    accuracy_rel = sum(accuracy_rels) / len(accuracy_rels)
    accuracy_norel = sum(accuracy_norels) / len(accuracy_norels)
    print('\n Test set: Ternary accuracy: {:.0f}% Binary accuracy: {:.0f}% | Unary accuracy: {:.0f}%\n'.format(
        accuracy_ternary, accuracy_rel, accuracy_norel))

    summary_writer.add_scalars('Accuracy/test', {
        'ternary': accuracy_ternary,
        'binary': accuracy_rel,
        'unary': accuracy_norel
    }, epoch)

    loss_ternary = sum(loss_ternary) / len(loss_ternary)
    loss_binary = sum(loss_binary) / len(loss_binary)
    loss_unary = sum(loss_unary) / len(loss_unary)

    summary_writer.add_scalars('Loss/test', {
        'ternary': loss_ternary,
        'binary': loss_binary,
        'unary': loss_unary
    }, epoch)

    return accuracy_ternary, accuracy_rel, accuracy_norel

# %%
def load_data():
    print('loading data...')
    dirs = './data'
    filename = os.path.join(dirs,'sort-of-clevr.pickle')
    with open(filename, 'rb') as f:
      train_datasets, test_datasets = pickle.load(f)
    ternary_train = []
    ternary_test = []
    rel_train = []
    rel_test = []
    norel_train = []
    norel_test = []
    print('processing data...')

    for img, ternary, relations, norelations, state_description in train_datasets:
        img = np.swapaxes(img, 0, 2)
        for qst, ans in zip(ternary[0], ternary[1]):
            ternary_train.append((img,qst,ans,state_description))
        for qst,ans in zip(relations[0], relations[1]):
            rel_train.append((img,qst,ans,state_description))
        for qst,ans in zip(norelations[0], norelations[1]):
            norel_train.append((img,qst,ans,state_description))

    for img, ternary, relations, norelations, state_description in test_datasets:
        img = np.swapaxes(img, 0, 2)
        for qst, ans in zip(ternary[0], ternary[1]):
            ternary_test.append((img, qst, ans,state_description))
        for qst,ans in zip(relations[0], relations[1]):
            rel_test.append((img,qst,ans,state_description))
        for qst,ans in zip(norelations[0], norelations[1]):
            norel_test.append((img,qst,ans,state_description))
    
    return (ternary_train, ternary_test, rel_train, rel_test, norel_train, norel_test)

# %% [markdown]
# ### 1.2 Load Dataset

# %%
ternary_train, ternary_test, rel_train, rel_test, norel_train, norel_test = load_data()
# Out:
# loading data...
# processing data...

# %% [markdown]
# ### 1.3 Instanciates Model

# %%
kwargs = {
    'relation_type': 'binary',
    'batch_size': 64,
    'cuda': True,
    'lr': 1e-4,
}

state = True #where to train on images or state description

if state:
    model = RN_State(**kwargs)
    model_type = 'RN_State'
else:
    model = RN(**kwargs)
    model_type = 'RN'

model
# Out:
# RN_State(
#   (g_fc1): Linear(in_features=26, out_features=2000, bias=True)
#   (g_fc2): Linear(in_features=2000, out_features=2000, bias=True)
#   (g_fc3): Linear(in_features=2000, out_features=2000, bias=True)
#   (g_fc4): Linear(in_features=2000, out_features=2000, bias=True)
#   (f_fc1): Linear(in_features=2000, out_features=2000, bias=True)
#   (f_fc2): Linear(in_features=2000, out_features=1000, bias=True)
#   (f_fc3): Linear(in_features=1000, out_features=500, bias=True)
#   (f_fc4): Linear(in_features=500, out_features=100, bias=True)
#   (fcout): FCOutputModel(
#     (fc2): Linear(in_features=100, out_features=100, bias=True)
#     (fc3): Linear(in_features=100, out_features=10, bias=True)
#   )
# )

# %%
model_dirs = './model'
bs = kwargs['batch_size']
input_img = torch.FloatTensor(bs, 3, 75, 75)
input_qst = torch.FloatTensor(bs, 18)
label = torch.LongTensor(bs)
input_state = torch.FloatTensor(bs, 6, 4)

# %%
if kwargs['cuda']:
    model.cuda()
    input_img = input_img.cuda()
    input_qst = input_qst.cuda()
    label = label.cuda()
    input_state = input_state.cuda()

# %% [markdown]
# ### 1.4 Train Model

# %%
try:
    os.makedirs(model_dirs)
except:
    print('directory {} already exists'.format(model_dirs))
# Out:
# directory ./model already exists

# %%
epochs = 50
seed = 1
log_interval = 300

# %%
with open(f'./{model_type}_{seed}_log.csv', 'w') as log_file:
    csv_writer = csv.writer(log_file, delimiter=',')
    csv_writer.writerow(['epoch', 'train_acc_ternary', 'train_acc_rel',
                     'train_acc_norel', 'train_acc_ternary', 'test_acc_rel', 'test_acc_norel'])

    # print("Training {} {}" if model_type == 'RN' else ''} model...")
    print('Training...')

    for epoch in range(1, epochs + 1):
        train_acc_ternary, train_acc_binary, train_acc_unary = train(
            epoch, ternary_train, rel_train, norel_train, state=state)
        test_acc_ternary, test_acc_binary, test_acc_unary = test(
            epoch, ternary_test, rel_test, norel_test, state=state)

        csv_writer.writerow([epoch, train_acc_ternary, train_acc_binary,
                         train_acc_unary, test_acc_ternary, test_acc_binary, test_acc_unary])
        model.save_model(epoch)
# Out:
# Training...
# Train Epoch: 1 [0/196000 (0%)] Ternary accuracy: 14% | Relations accuracy: 5% | Non-relations accuracy: 5%
# Train Epoch: 1 [38400/196000 (20%)] Ternary accuracy: 22% | Relations accuracy: 27% | Non-relations accuracy: 42%
# Train Epoch: 1 [76800/196000 (39%)] Ternary accuracy: 45% | Relations accuracy: 30% | Non-relations accuracy: 34%
# Train Epoch: 1 [115200/196000 (59%)] Ternary accuracy: 28% | Relations accuracy: 36% | Non-relations accuracy: 34%
# Train Epoch: 1 [153600/196000 (78%)] Ternary accuracy: 14% | Relations accuracy: 22% | Non-relations accuracy: 22%
# Train Epoch: 1 [192000/196000 (98%)] Ternary accuracy: 14% | Relations accuracy: 42% | Non-relations accuracy: 9%
#
#  Test set: Ternary accuracy: 30% Binary accuracy: 25% | Unary accuracy: 24%
#
# Train Epoch: 2 [0/196000 (0%)] Ternary accuracy: 25% | Relations accuracy: 36% | Non-relations accuracy: 12%
# Train Epoch: 2 [38400/196000 (20%)] Ternary accuracy: 45% | Relations accuracy: 41% | Non-relations accuracy: 27%
# Train Epoch: 2 [76800/196000 (39%)] Ternary accuracy: 28% | Relations accuracy: 50% | Non-relations accuracy: 16%
# Train Epoch: 2 [115200/196000 (59%)] Ternary accuracy: 44% | Relations accuracy: 36% | Non-relations accuracy: 28%
# Train Epoch: 2 [153600/196000 (78%)] Ternary accuracy: 50% | Relations accuracy: 50% | Non-relations accuracy: 34%
# Train Epoch: 2 [192000/196000 (98%)] Ternary accuracy: 50% | Relations accuracy: 45% | Non-relations accuracy: 27%
#
#  Test set: Ternary accuracy: 54% Binary accuracy: 42% | Unary accuracy: 33%
#
# Train Epoch: 3 [0/196000 (0%)] Ternary accuracy: 61% | Relations accuracy: 47% | Non-relations accuracy: 36%
# Train Epoch: 3 [38400/196000 (20%)] Ternary accuracy: 53% | Relations accuracy: 41% | Non-relations accuracy: 23%
# Train Epoch: 3 [76800/196000 (39%)] Ternary accuracy: 36% | Relations accuracy: 41% | Non-relations accuracy: 12%
# Train Epoch: 3 [115200/196000 (59%)] Ternary accuracy: 47% | Relations accuracy: 41% | Non-relations accuracy: 42%
# Train Epoch: 3 [153600/196000 (78%)] Ternary accuracy: 38% | Relations accuracy: 31% | Non-relations accuracy: 41%
# Train Epoch: 3 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 38% | Non-relations accuracy: 34%
#
#  Test set: Ternary accuracy: 52% Binary accuracy: 42% | Unary accuracy: 35%
#
# Train Epoch: 4 [0/196000 (0%)] Ternary accuracy: 44% | Relations accuracy: 42% | Non-relations accuracy: 31%
# Train Epoch: 4 [38400/196000 (20%)] Ternary accuracy: 44% | Relations accuracy: 38% | Non-relations accuracy: 31%
# Train Epoch: 4 [76800/196000 (39%)] Ternary accuracy: 8% | Relations accuracy: 42% | Non-relations accuracy: 12%
# Train Epoch: 4 [115200/196000 (59%)] Ternary accuracy: 22% | Relations accuracy: 16% | Non-relations accuracy: 30%
# Train Epoch: 4 [153600/196000 (78%)] Ternary accuracy: 52% | Relations accuracy: 38% | Non-relations accuracy: 38%
# Train Epoch: 4 [192000/196000 (98%)] Ternary accuracy: 56% | Relations accuracy: 38% | Non-relations accuracy: 34%
#
#  Test set: Ternary accuracy: 12% Binary accuracy: 16% | Unary accuracy: 26%
#
# Train Epoch: 5 [0/196000 (0%)] Ternary accuracy: 17% | Relations accuracy: 14% | Non-relations accuracy: 41%
# Train Epoch: 5 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 41% | Non-relations accuracy: 25%
# Train Epoch: 5 [76800/196000 (39%)] Ternary accuracy: 11% | Relations accuracy: 12% | Non-relations accuracy: 27%
# Train Epoch: 5 [115200/196000 (59%)] Ternary accuracy: 59% | Relations accuracy: 52% | Non-relations accuracy: 42%
# Train Epoch: 5 [153600/196000 (78%)] Ternary accuracy: 58% | Relations accuracy: 39% | Non-relations accuracy: 38%
# Train Epoch: 5 [192000/196000 (98%)] Ternary accuracy: 14% | Relations accuracy: 33% | Non-relations accuracy: 20%
#
#  Test set: Ternary accuracy: 11% Binary accuracy: 37% | Unary accuracy: 18%
#
# Train Epoch: 6 [0/196000 (0%)] Ternary accuracy: 14% | Relations accuracy: 36% | Non-relations accuracy: 20%
# Train Epoch: 6 [38400/196000 (20%)] Ternary accuracy: 52% | Relations accuracy: 41% | Non-relations accuracy: 31%
# Train Epoch: 6 [76800/196000 (39%)] Ternary accuracy: 45% | Relations accuracy: 44% | Non-relations accuracy: 34%
# Train Epoch: 6 [115200/196000 (59%)] Ternary accuracy: 44% | Relations accuracy: 50% | Non-relations accuracy: 31%
# Train Epoch: 6 [153600/196000 (78%)] Ternary accuracy: 47% | Relations accuracy: 36% | Non-relations accuracy: 31%
# Train Epoch: 6 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 58% | Non-relations accuracy: 36%
#
#  Test set: Ternary accuracy: 51% Binary accuracy: 44% | Unary accuracy: 34%
#
# Train Epoch: 7 [0/196000 (0%)] Ternary accuracy: 52% | Relations accuracy: 39% | Non-relations accuracy: 30%
# Train Epoch: 7 [38400/196000 (20%)] Ternary accuracy: 44% | Relations accuracy: 42% | Non-relations accuracy: 38%
# Train Epoch: 7 [76800/196000 (39%)] Ternary accuracy: 2% | Relations accuracy: 12% | Non-relations accuracy: 23%
# Train Epoch: 7 [115200/196000 (59%)] Ternary accuracy: 45% | Relations accuracy: 47% | Non-relations accuracy: 34%
# Train Epoch: 7 [153600/196000 (78%)] Ternary accuracy: 44% | Relations accuracy: 34% | Non-relations accuracy: 12%
# Train Epoch: 7 [192000/196000 (98%)] Ternary accuracy: 44% | Relations accuracy: 34% | Non-relations accuracy: 31%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 44% | Unary accuracy: 36%
#
# Train Epoch: 8 [0/196000 (0%)] Ternary accuracy: 66% | Relations accuracy: 45% | Non-relations accuracy: 33%
# Train Epoch: 8 [38400/196000 (20%)] Ternary accuracy: 52% | Relations accuracy: 41% | Non-relations accuracy: 36%
# Train Epoch: 8 [76800/196000 (39%)] Ternary accuracy: 47% | Relations accuracy: 45% | Non-relations accuracy: 33%
# Train Epoch: 8 [115200/196000 (59%)] Ternary accuracy: 52% | Relations accuracy: 41% | Non-relations accuracy: 48%
# Train Epoch: 8 [153600/196000 (78%)] Ternary accuracy: 48% | Relations accuracy: 36% | Non-relations accuracy: 50%
# Train Epoch: 8 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 53% | Non-relations accuracy: 53%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 43% | Unary accuracy: 53%
#
# Train Epoch: 9 [0/196000 (0%)] Ternary accuracy: 42% | Relations accuracy: 39% | Non-relations accuracy: 48%
# Train Epoch: 9 [38400/196000 (20%)] Ternary accuracy: 61% | Relations accuracy: 52% | Non-relations accuracy: 50%
# Train Epoch: 9 [76800/196000 (39%)] Ternary accuracy: 50% | Relations accuracy: 39% | Non-relations accuracy: 45%
# Train Epoch: 9 [115200/196000 (59%)] Ternary accuracy: 50% | Relations accuracy: 33% | Non-relations accuracy: 56%
# Train Epoch: 9 [153600/196000 (78%)] Ternary accuracy: 55% | Relations accuracy: 53% | Non-relations accuracy: 50%
# Train Epoch: 9 [192000/196000 (98%)] Ternary accuracy: 47% | Relations accuracy: 38% | Non-relations accuracy: 56%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 41% | Unary accuracy: 55%
#
# Train Epoch: 10 [0/196000 (0%)] Ternary accuracy: 38% | Relations accuracy: 44% | Non-relations accuracy: 44%
# Train Epoch: 10 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 45% | Non-relations accuracy: 64%
# Train Epoch: 10 [76800/196000 (39%)] Ternary accuracy: 45% | Relations accuracy: 59% | Non-relations accuracy: 59%
# Train Epoch: 10 [115200/196000 (59%)] Ternary accuracy: 48% | Relations accuracy: 42% | Non-relations accuracy: 59%
# Train Epoch: 10 [153600/196000 (78%)] Ternary accuracy: 45% | Relations accuracy: 44% | Non-relations accuracy: 36%
# Train Epoch: 10 [192000/196000 (98%)] Ternary accuracy: 42% | Relations accuracy: 38% | Non-relations accuracy: 45%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 42% | Unary accuracy: 34%
#
# Train Epoch: 11 [0/196000 (0%)] Ternary accuracy: 44% | Relations accuracy: 42% | Non-relations accuracy: 27%
# Train Epoch: 11 [38400/196000 (20%)] Ternary accuracy: 56% | Relations accuracy: 38% | Non-relations accuracy: 52%
# Train Epoch: 11 [76800/196000 (39%)] Ternary accuracy: 58% | Relations accuracy: 45% | Non-relations accuracy: 55%
# Train Epoch: 11 [115200/196000 (59%)] Ternary accuracy: 56% | Relations accuracy: 44% | Non-relations accuracy: 53%
# Train Epoch: 11 [153600/196000 (78%)] Ternary accuracy: 48% | Relations accuracy: 42% | Non-relations accuracy: 62%
# Train Epoch: 11 [192000/196000 (98%)] Ternary accuracy: 53% | Relations accuracy: 41% | Non-relations accuracy: 58%
#
#  Test set: Ternary accuracy: 52% Binary accuracy: 41% | Unary accuracy: 50%
#
# Train Epoch: 12 [0/196000 (0%)] Ternary accuracy: 47% | Relations accuracy: 48% | Non-relations accuracy: 56%
# Train Epoch: 12 [38400/196000 (20%)] Ternary accuracy: 44% | Relations accuracy: 47% | Non-relations accuracy: 52%
# Train Epoch: 12 [76800/196000 (39%)] Ternary accuracy: 59% | Relations accuracy: 45% | Non-relations accuracy: 59%
# Train Epoch: 12 [115200/196000 (59%)] Ternary accuracy: 47% | Relations accuracy: 38% | Non-relations accuracy: 58%
# Train Epoch: 12 [153600/196000 (78%)] Ternary accuracy: 62% | Relations accuracy: 41% | Non-relations accuracy: 61%
# Train Epoch: 12 [192000/196000 (98%)] Ternary accuracy: 45% | Relations accuracy: 30% | Non-relations accuracy: 53%
#
#  Test set: Ternary accuracy: 51% Binary accuracy: 43% | Unary accuracy: 55%
#
# Train Epoch: 13 [0/196000 (0%)] Ternary accuracy: 50% | Relations accuracy: 42% | Non-relations accuracy: 64%
# Train Epoch: 13 [38400/196000 (20%)] Ternary accuracy: 47% | Relations accuracy: 47% | Non-relations accuracy: 45%
# Train Epoch: 13 [76800/196000 (39%)] Ternary accuracy: 53% | Relations accuracy: 42% | Non-relations accuracy: 61%
# Train Epoch: 13 [115200/196000 (59%)] Ternary accuracy: 44% | Relations accuracy: 50% | Non-relations accuracy: 50%
# Train Epoch: 13 [153600/196000 (78%)] Ternary accuracy: 48% | Relations accuracy: 41% | Non-relations accuracy: 66%
# Train Epoch: 13 [192000/196000 (98%)] Ternary accuracy: 52% | Relations accuracy: 45% | Non-relations accuracy: 56%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 42% | Unary accuracy: 55%
#
# Train Epoch: 14 [0/196000 (0%)] Ternary accuracy: 48% | Relations accuracy: 44% | Non-relations accuracy: 56%
# Train Epoch: 14 [38400/196000 (20%)] Ternary accuracy: 55% | Relations accuracy: 48% | Non-relations accuracy: 62%
# Train Epoch: 14 [76800/196000 (39%)] Ternary accuracy: 52% | Relations accuracy: 39% | Non-relations accuracy: 55%
# Train Epoch: 14 [115200/196000 (59%)] Ternary accuracy: 52% | Relations accuracy: 41% | Non-relations accuracy: 56%
# Train Epoch: 14 [153600/196000 (78%)] Ternary accuracy: 59% | Relations accuracy: 53% | Non-relations accuracy: 55%
# Train Epoch: 14 [192000/196000 (98%)] Ternary accuracy: 53% | Relations accuracy: 36% | Non-relations accuracy: 52%
#
#  Test set: Ternary accuracy: 54% Binary accuracy: 42% | Unary accuracy: 58%
#
# Train Epoch: 15 [0/196000 (0%)] Ternary accuracy: 53% | Relations accuracy: 44% | Non-relations accuracy: 62%
# Train Epoch: 15 [38400/196000 (20%)] Ternary accuracy: 50% | Relations accuracy: 52% | Non-relations accuracy: 56%
# Train Epoch: 15 [76800/196000 (39%)] Ternary accuracy: 52% | Relations accuracy: 42% | Non-relations accuracy: 53%
# Train Epoch: 15 [115200/196000 (59%)] Ternary accuracy: 56% | Relations accuracy: 42% | Non-relations accuracy: 58%
# Train Epoch: 15 [153600/196000 (78%)] Ternary accuracy: 55% | Relations accuracy: 42% | Non-relations accuracy: 56%
# Train Epoch: 15 [192000/196000 (98%)] Ternary accuracy: 61% | Relations accuracy: 45% | Non-relations accuracy: 48%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 41% | Unary accuracy: 56%
#
# Train Epoch: 16 [0/196000 (0%)] Ternary accuracy: 45% | Relations accuracy: 52% | Non-relations accuracy: 58%
# Train Epoch: 16 [38400/196000 (20%)] Ternary accuracy: 55% | Relations accuracy: 50% | Non-relations accuracy: 48%
# Train Epoch: 16 [76800/196000 (39%)] Ternary accuracy: 62% | Relations accuracy: 41% | Non-relations accuracy: 61%
# Train Epoch: 16 [115200/196000 (59%)] Ternary accuracy: 33% | Relations accuracy: 55% | Non-relations accuracy: 47%
# Train Epoch: 16 [153600/196000 (78%)] Ternary accuracy: 58% | Relations accuracy: 56% | Non-relations accuracy: 59%
# Train Epoch: 16 [192000/196000 (98%)] Ternary accuracy: 64% | Relations accuracy: 47% | Non-relations accuracy: 55%
#
#  Test set: Ternary accuracy: 54% Binary accuracy: 43% | Unary accuracy: 56%
#
# Train Epoch: 17 [0/196000 (0%)] Ternary accuracy: 44% | Relations accuracy: 36% | Non-relations accuracy: 58%
# Train Epoch: 17 [38400/196000 (20%)] Ternary accuracy: 45% | Relations accuracy: 36% | Non-relations accuracy: 58%
# Train Epoch: 17 [76800/196000 (39%)] Ternary accuracy: 47% | Relations accuracy: 47% | Non-relations accuracy: 59%
# Train Epoch: 17 [115200/196000 (59%)] Ternary accuracy: 50% | Relations accuracy: 41% | Non-relations accuracy: 48%
# Train Epoch: 17 [153600/196000 (78%)] Ternary accuracy: 56% | Relations accuracy: 39% | Non-relations accuracy: 58%
# Train Epoch: 17 [192000/196000 (98%)] Ternary accuracy: 69% | Relations accuracy: 61% | Non-relations accuracy: 47%
#
#  Test set: Ternary accuracy: 54% Binary accuracy: 44% | Unary accuracy: 54%
#
# Train Epoch: 18 [0/196000 (0%)] Ternary accuracy: 56% | Relations accuracy: 38% | Non-relations accuracy: 45%
# Train Epoch: 18 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 42% | Non-relations accuracy: 66%
# Train Epoch: 18 [76800/196000 (39%)] Ternary accuracy: 50% | Relations accuracy: 42% | Non-relations accuracy: 67%
# Train Epoch: 18 [115200/196000 (59%)] Ternary accuracy: 52% | Relations accuracy: 41% | Non-relations accuracy: 62%
# Train Epoch: 18 [153600/196000 (78%)] Ternary accuracy: 59% | Relations accuracy: 53% | Non-relations accuracy: 41%
# Train Epoch: 18 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 45% | Non-relations accuracy: 47%
#
#  Test set: Ternary accuracy: 51% Binary accuracy: 42% | Unary accuracy: 57%
#
# Train Epoch: 19 [0/196000 (0%)] Ternary accuracy: 66% | Relations accuracy: 42% | Non-relations accuracy: 61%
# Train Epoch: 19 [38400/196000 (20%)] Ternary accuracy: 38% | Relations accuracy: 48% | Non-relations accuracy: 53%
# Train Epoch: 19 [76800/196000 (39%)] Ternary accuracy: 53% | Relations accuracy: 45% | Non-relations accuracy: 50%
# Train Epoch: 19 [115200/196000 (59%)] Ternary accuracy: 66% | Relations accuracy: 41% | Non-relations accuracy: 59%
# Train Epoch: 19 [153600/196000 (78%)] Ternary accuracy: 42% | Relations accuracy: 45% | Non-relations accuracy: 47%
# Train Epoch: 19 [192000/196000 (98%)] Ternary accuracy: 52% | Relations accuracy: 44% | Non-relations accuracy: 70%
#
#  Test set: Ternary accuracy: 30% Binary accuracy: 45% | Unary accuracy: 41%
#
# Train Epoch: 20 [0/196000 (0%)] Ternary accuracy: 31% | Relations accuracy: 45% | Non-relations accuracy: 31%
# Train Epoch: 20 [38400/196000 (20%)] Ternary accuracy: 61% | Relations accuracy: 39% | Non-relations accuracy: 64%
# Train Epoch: 20 [76800/196000 (39%)] Ternary accuracy: 50% | Relations accuracy: 38% | Non-relations accuracy: 62%
# Train Epoch: 20 [115200/196000 (59%)] Ternary accuracy: 58% | Relations accuracy: 45% | Non-relations accuracy: 53%
# Train Epoch: 20 [153600/196000 (78%)] Ternary accuracy: 55% | Relations accuracy: 30% | Non-relations accuracy: 55%
# Train Epoch: 20 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 42% | Non-relations accuracy: 61%
#
#  Test set: Ternary accuracy: 55% Binary accuracy: 41% | Unary accuracy: 59%
#
# Train Epoch: 21 [0/196000 (0%)] Ternary accuracy: 64% | Relations accuracy: 55% | Non-relations accuracy: 59%
# Train Epoch: 21 [38400/196000 (20%)] Ternary accuracy: 64% | Relations accuracy: 48% | Non-relations accuracy: 67%
# Train Epoch: 21 [76800/196000 (39%)] Ternary accuracy: 62% | Relations accuracy: 45% | Non-relations accuracy: 69%
# Train Epoch: 21 [115200/196000 (59%)] Ternary accuracy: 58% | Relations accuracy: 41% | Non-relations accuracy: 62%
# Train Epoch: 21 [153600/196000 (78%)] Ternary accuracy: 59% | Relations accuracy: 42% | Non-relations accuracy: 50%
# Train Epoch: 21 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 44% | Non-relations accuracy: 52%
#
#  Test set: Ternary accuracy: 53% Binary accuracy: 41% | Unary accuracy: 60%
#
# Train Epoch: 22 [0/196000 (0%)] Ternary accuracy: 41% | Relations accuracy: 47% | Non-relations accuracy: 67%
# Train Epoch: 22 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 41% | Non-relations accuracy: 61%
# Train Epoch: 22 [76800/196000 (39%)] Ternary accuracy: 55% | Relations accuracy: 39% | Non-relations accuracy: 64%
# Train Epoch: 22 [115200/196000 (59%)] Ternary accuracy: 52% | Relations accuracy: 36% | Non-relations accuracy: 61%
# Train Epoch: 22 [153600/196000 (78%)] Ternary accuracy: 64% | Relations accuracy: 52% | Non-relations accuracy: 66%
# Train Epoch: 22 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 38% | Non-relations accuracy: 61%
#
#  Test set: Ternary accuracy: 55% Binary accuracy: 42% | Unary accuracy: 60%
#
# Train Epoch: 23 [0/196000 (0%)] Ternary accuracy: 45% | Relations accuracy: 38% | Non-relations accuracy: 70%
# Train Epoch: 23 [38400/196000 (20%)] Ternary accuracy: 55% | Relations accuracy: 45% | Non-relations accuracy: 61%
# Train Epoch: 23 [76800/196000 (39%)] Ternary accuracy: 47% | Relations accuracy: 44% | Non-relations accuracy: 53%
# Train Epoch: 23 [115200/196000 (59%)] Ternary accuracy: 56% | Relations accuracy: 36% | Non-relations accuracy: 66%
# Train Epoch: 23 [153600/196000 (78%)] Ternary accuracy: 56% | Relations accuracy: 50% | Non-relations accuracy: 67%
# Train Epoch: 23 [192000/196000 (98%)] Ternary accuracy: 61% | Relations accuracy: 52% | Non-relations accuracy: 69%
#
#  Test set: Ternary accuracy: 55% Binary accuracy: 42% | Unary accuracy: 66%
#
# Train Epoch: 24 [0/196000 (0%)] Ternary accuracy: 50% | Relations accuracy: 39% | Non-relations accuracy: 61%
# Train Epoch: 24 [38400/196000 (20%)] Ternary accuracy: 59% | Relations accuracy: 44% | Non-relations accuracy: 67%
# Train Epoch: 24 [76800/196000 (39%)] Ternary accuracy: 66% | Relations accuracy: 48% | Non-relations accuracy: 67%
# Train Epoch: 24 [115200/196000 (59%)] Ternary accuracy: 47% | Relations accuracy: 31% | Non-relations accuracy: 62%
# Train Epoch: 24 [153600/196000 (78%)] Ternary accuracy: 62% | Relations accuracy: 34% | Non-relations accuracy: 64%
# Train Epoch: 24 [192000/196000 (98%)] Ternary accuracy: 56% | Relations accuracy: 52% | Non-relations accuracy: 62%
#
#  Test set: Ternary accuracy: 52% Binary accuracy: 40% | Unary accuracy: 68%
#
# Train Epoch: 25 [0/196000 (0%)] Ternary accuracy: 55% | Relations accuracy: 44% | Non-relations accuracy: 69%
# Train Epoch: 25 [38400/196000 (20%)] Ternary accuracy: 67% | Relations accuracy: 44% | Non-relations accuracy: 64%
# Train Epoch: 25 [76800/196000 (39%)] Ternary accuracy: 61% | Relations accuracy: 45% | Non-relations accuracy: 70%
# Train Epoch: 25 [115200/196000 (59%)] Ternary accuracy: 45% | Relations accuracy: 39% | Non-relations accuracy: 67%
# Train Epoch: 25 [153600/196000 (78%)] Ternary accuracy: 64% | Relations accuracy: 52% | Non-relations accuracy: 70%
# Train Epoch: 25 [192000/196000 (98%)] Ternary accuracy: 62% | Relations accuracy: 45% | Non-relations accuracy: 67%
#
#  Test set: Ternary accuracy: 55% Binary accuracy: 42% | Unary accuracy: 68%
#
# Train Epoch: 26 [0/196000 (0%)] Ternary accuracy: 56% | Relations accuracy: 47% | Non-relations accuracy: 72%
# Train Epoch: 26 [38400/196000 (20%)] Ternary accuracy: 52% | Relations accuracy: 52% | Non-relations accuracy: 70%
# Train Epoch: 26 [76800/196000 (39%)] Ternary accuracy: 64% | Relations accuracy: 47% | Non-relations accuracy: 67%
# Train Epoch: 26 [115200/196000 (59%)] Ternary accuracy: 47% | Relations accuracy: 44% | Non-relations accuracy: 72%
# Train Epoch: 26 [153600/196000 (78%)] Ternary accuracy: 55% | Relations accuracy: 45% | Non-relations accuracy: 69%
# Train Epoch: 26 [192000/196000 (98%)] Ternary accuracy: 50% | Relations accuracy: 34% | Non-relations accuracy: 66%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 43% | Unary accuracy: 70%
#
# Train Epoch: 27 [0/196000 (0%)] Ternary accuracy: 58% | Relations accuracy: 52% | Non-relations accuracy: 64%
# Train Epoch: 27 [38400/196000 (20%)] Ternary accuracy: 61% | Relations accuracy: 47% | Non-relations accuracy: 75%
# Train Epoch: 27 [76800/196000 (39%)] Ternary accuracy: 59% | Relations accuracy: 41% | Non-relations accuracy: 77%
# Train Epoch: 27 [115200/196000 (59%)] Ternary accuracy: 55% | Relations accuracy: 44% | Non-relations accuracy: 69%
# Train Epoch: 27 [153600/196000 (78%)] Ternary accuracy: 59% | Relations accuracy: 50% | Non-relations accuracy: 70%
# Train Epoch: 27 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 42% | Non-relations accuracy: 67%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 42% | Unary accuracy: 72%
#
# Train Epoch: 28 [0/196000 (0%)] Ternary accuracy: 73% | Relations accuracy: 31% | Non-relations accuracy: 69%
# Train Epoch: 28 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 52% | Non-relations accuracy: 84%
# Train Epoch: 28 [76800/196000 (39%)] Ternary accuracy: 58% | Relations accuracy: 52% | Non-relations accuracy: 83%
# Train Epoch: 28 [115200/196000 (59%)] Ternary accuracy: 56% | Relations accuracy: 52% | Non-relations accuracy: 84%
# Train Epoch: 28 [153600/196000 (78%)] Ternary accuracy: 61% | Relations accuracy: 53% | Non-relations accuracy: 86%
# Train Epoch: 28 [192000/196000 (98%)] Ternary accuracy: 61% | Relations accuracy: 58% | Non-relations accuracy: 91%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 50% | Unary accuracy: 86%
#
# Train Epoch: 29 [0/196000 (0%)] Ternary accuracy: 53% | Relations accuracy: 58% | Non-relations accuracy: 86%
# Train Epoch: 29 [38400/196000 (20%)] Ternary accuracy: 72% | Relations accuracy: 52% | Non-relations accuracy: 78%
# Train Epoch: 29 [76800/196000 (39%)] Ternary accuracy: 48% | Relations accuracy: 50% | Non-relations accuracy: 97%
# Train Epoch: 29 [115200/196000 (59%)] Ternary accuracy: 53% | Relations accuracy: 64% | Non-relations accuracy: 94%
# Train Epoch: 29 [153600/196000 (78%)] Ternary accuracy: 62% | Relations accuracy: 62% | Non-relations accuracy: 86%
# Train Epoch: 29 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 62% | Non-relations accuracy: 88%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 52% | Unary accuracy: 87%
#
# Train Epoch: 30 [0/196000 (0%)] Ternary accuracy: 59% | Relations accuracy: 48% | Non-relations accuracy: 84%
# Train Epoch: 30 [38400/196000 (20%)] Ternary accuracy: 53% | Relations accuracy: 66% | Non-relations accuracy: 92%
# Train Epoch: 30 [76800/196000 (39%)] Ternary accuracy: 52% | Relations accuracy: 53% | Non-relations accuracy: 97%
# Train Epoch: 30 [115200/196000 (59%)] Ternary accuracy: 72% | Relations accuracy: 58% | Non-relations accuracy: 97%
# Train Epoch: 30 [153600/196000 (78%)] Ternary accuracy: 53% | Relations accuracy: 62% | Non-relations accuracy: 97%
# Train Epoch: 30 [192000/196000 (98%)] Ternary accuracy: 59% | Relations accuracy: 52% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 58% Binary accuracy: 56% | Unary accuracy: 99%
#
# Train Epoch: 31 [0/196000 (0%)] Ternary accuracy: 55% | Relations accuracy: 58% | Non-relations accuracy: 97%
# Train Epoch: 31 [38400/196000 (20%)] Ternary accuracy: 52% | Relations accuracy: 50% | Non-relations accuracy: 100%
# Train Epoch: 31 [76800/196000 (39%)] Ternary accuracy: 52% | Relations accuracy: 66% | Non-relations accuracy: 100%
# Train Epoch: 31 [115200/196000 (59%)] Ternary accuracy: 59% | Relations accuracy: 52% | Non-relations accuracy: 97%
# Train Epoch: 31 [153600/196000 (78%)] Ternary accuracy: 66% | Relations accuracy: 50% | Non-relations accuracy: 98%
# Train Epoch: 31 [192000/196000 (98%)] Ternary accuracy: 59% | Relations accuracy: 56% | Non-relations accuracy: 97%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 58% | Unary accuracy: 99%
#
# Train Epoch: 32 [0/196000 (0%)] Ternary accuracy: 64% | Relations accuracy: 53% | Non-relations accuracy: 100%
# Train Epoch: 32 [38400/196000 (20%)] Ternary accuracy: 61% | Relations accuracy: 47% | Non-relations accuracy: 98%
# Train Epoch: 32 [76800/196000 (39%)] Ternary accuracy: 64% | Relations accuracy: 53% | Non-relations accuracy: 94%
# Train Epoch: 32 [115200/196000 (59%)] Ternary accuracy: 62% | Relations accuracy: 41% | Non-relations accuracy: 100%
# Train Epoch: 32 [153600/196000 (78%)] Ternary accuracy: 62% | Relations accuracy: 59% | Non-relations accuracy: 97%
# Train Epoch: 32 [192000/196000 (98%)] Ternary accuracy: 59% | Relations accuracy: 59% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 58% Binary accuracy: 57% | Unary accuracy: 99%
#
# Train Epoch: 33 [0/196000 (0%)] Ternary accuracy: 50% | Relations accuracy: 59% | Non-relations accuracy: 100%
# Train Epoch: 33 [38400/196000 (20%)] Ternary accuracy: 48% | Relations accuracy: 47% | Non-relations accuracy: 98%
# Train Epoch: 33 [76800/196000 (39%)] Ternary accuracy: 55% | Relations accuracy: 53% | Non-relations accuracy: 98%
# Train Epoch: 33 [115200/196000 (59%)] Ternary accuracy: 47% | Relations accuracy: 61% | Non-relations accuracy: 98%
# Train Epoch: 33 [153600/196000 (78%)] Ternary accuracy: 55% | Relations accuracy: 55% | Non-relations accuracy: 100%
# Train Epoch: 33 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 52% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 58% Binary accuracy: 57% | Unary accuracy: 99%
#
# Train Epoch: 34 [0/196000 (0%)] Ternary accuracy: 69% | Relations accuracy: 55% | Non-relations accuracy: 100%
# Train Epoch: 34 [38400/196000 (20%)] Ternary accuracy: 69% | Relations accuracy: 53% | Non-relations accuracy: 100%
# Train Epoch: 34 [76800/196000 (39%)] Ternary accuracy: 67% | Relations accuracy: 61% | Non-relations accuracy: 98%
# Train Epoch: 34 [115200/196000 (59%)] Ternary accuracy: 58% | Relations accuracy: 58% | Non-relations accuracy: 100%
# Train Epoch: 34 [153600/196000 (78%)] Ternary accuracy: 55% | Relations accuracy: 53% | Non-relations accuracy: 98%
# Train Epoch: 34 [192000/196000 (98%)] Ternary accuracy: 48% | Relations accuracy: 59% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 58% Binary accuracy: 59% | Unary accuracy: 99%
#
# Train Epoch: 35 [0/196000 (0%)] Ternary accuracy: 53% | Relations accuracy: 64% | Non-relations accuracy: 98%
# Train Epoch: 35 [38400/196000 (20%)] Ternary accuracy: 56% | Relations accuracy: 70% | Non-relations accuracy: 100%
# Train Epoch: 35 [76800/196000 (39%)] Ternary accuracy: 66% | Relations accuracy: 67% | Non-relations accuracy: 100%
# Train Epoch: 35 [115200/196000 (59%)] Ternary accuracy: 64% | Relations accuracy: 59% | Non-relations accuracy: 100%
# Train Epoch: 35 [153600/196000 (78%)] Ternary accuracy: 69% | Relations accuracy: 69% | Non-relations accuracy: 97%
# Train Epoch: 35 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 56% | Non-relations accuracy: 97%
#
#  Test set: Ternary accuracy: 59% Binary accuracy: 60% | Unary accuracy: 100%
#
# Train Epoch: 36 [0/196000 (0%)] Ternary accuracy: 66% | Relations accuracy: 48% | Non-relations accuracy: 100%
# Train Epoch: 36 [38400/196000 (20%)] Ternary accuracy: 61% | Relations accuracy: 70% | Non-relations accuracy: 100%
# Train Epoch: 36 [76800/196000 (39%)] Ternary accuracy: 55% | Relations accuracy: 50% | Non-relations accuracy: 98%
# Train Epoch: 36 [115200/196000 (59%)] Ternary accuracy: 39% | Relations accuracy: 64% | Non-relations accuracy: 100%
# Train Epoch: 36 [153600/196000 (78%)] Ternary accuracy: 50% | Relations accuracy: 69% | Non-relations accuracy: 100%
# Train Epoch: 36 [192000/196000 (98%)] Ternary accuracy: 52% | Relations accuracy: 66% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 60% | Unary accuracy: 99%
#
# Train Epoch: 37 [0/196000 (0%)] Ternary accuracy: 62% | Relations accuracy: 66% | Non-relations accuracy: 100%
# Train Epoch: 37 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 67% | Non-relations accuracy: 100%
# Train Epoch: 37 [76800/196000 (39%)] Ternary accuracy: 62% | Relations accuracy: 73% | Non-relations accuracy: 98%
# Train Epoch: 37 [115200/196000 (59%)] Ternary accuracy: 62% | Relations accuracy: 64% | Non-relations accuracy: 97%
# Train Epoch: 37 [153600/196000 (78%)] Ternary accuracy: 80% | Relations accuracy: 69% | Non-relations accuracy: 98%
# Train Epoch: 37 [192000/196000 (98%)] Ternary accuracy: 50% | Relations accuracy: 67% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 58% Binary accuracy: 59% | Unary accuracy: 100%
#
# Train Epoch: 38 [0/196000 (0%)] Ternary accuracy: 64% | Relations accuracy: 62% | Non-relations accuracy: 100%
# Train Epoch: 38 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 59% | Non-relations accuracy: 100%
# Train Epoch: 38 [76800/196000 (39%)] Ternary accuracy: 69% | Relations accuracy: 45% | Non-relations accuracy: 100%
# Train Epoch: 38 [115200/196000 (59%)] Ternary accuracy: 50% | Relations accuracy: 69% | Non-relations accuracy: 100%
# Train Epoch: 38 [153600/196000 (78%)] Ternary accuracy: 52% | Relations accuracy: 77% | Non-relations accuracy: 100%
# Train Epoch: 38 [192000/196000 (98%)] Ternary accuracy: 62% | Relations accuracy: 69% | Non-relations accuracy: 97%
#
#  Test set: Ternary accuracy: 60% Binary accuracy: 74% | Unary accuracy: 99%
#
# Train Epoch: 39 [0/196000 (0%)] Ternary accuracy: 56% | Relations accuracy: 72% | Non-relations accuracy: 100%
# Train Epoch: 39 [38400/196000 (20%)] Ternary accuracy: 55% | Relations accuracy: 77% | Non-relations accuracy: 100%
# Train Epoch: 39 [76800/196000 (39%)] Ternary accuracy: 53% | Relations accuracy: 77% | Non-relations accuracy: 100%
# Train Epoch: 39 [115200/196000 (59%)] Ternary accuracy: 64% | Relations accuracy: 72% | Non-relations accuracy: 98%
# Train Epoch: 39 [153600/196000 (78%)] Ternary accuracy: 62% | Relations accuracy: 73% | Non-relations accuracy: 100%
# Train Epoch: 39 [192000/196000 (98%)] Ternary accuracy: 64% | Relations accuracy: 78% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 56% Binary accuracy: 76% | Unary accuracy: 99%
#
# Train Epoch: 40 [0/196000 (0%)] Ternary accuracy: 58% | Relations accuracy: 72% | Non-relations accuracy: 100%
# Train Epoch: 40 [38400/196000 (20%)] Ternary accuracy: 55% | Relations accuracy: 73% | Non-relations accuracy: 97%
# Train Epoch: 40 [76800/196000 (39%)] Ternary accuracy: 61% | Relations accuracy: 78% | Non-relations accuracy: 100%
# Train Epoch: 40 [115200/196000 (59%)] Ternary accuracy: 55% | Relations accuracy: 80% | Non-relations accuracy: 100%
# Train Epoch: 40 [153600/196000 (78%)] Ternary accuracy: 64% | Relations accuracy: 81% | Non-relations accuracy: 100%
# Train Epoch: 40 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 61% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 65% | Unary accuracy: 100%
#
# Train Epoch: 41 [0/196000 (0%)] Ternary accuracy: 70% | Relations accuracy: 75% | Non-relations accuracy: 100%
# Train Epoch: 41 [38400/196000 (20%)] Ternary accuracy: 59% | Relations accuracy: 61% | Non-relations accuracy: 100%
# Train Epoch: 41 [76800/196000 (39%)] Ternary accuracy: 48% | Relations accuracy: 78% | Non-relations accuracy: 100%
# Train Epoch: 41 [115200/196000 (59%)] Ternary accuracy: 67% | Relations accuracy: 75% | Non-relations accuracy: 98%
# Train Epoch: 41 [153600/196000 (78%)] Ternary accuracy: 64% | Relations accuracy: 80% | Non-relations accuracy: 98%
# Train Epoch: 41 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 77% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 57% Binary accuracy: 78% | Unary accuracy: 100%
#
# Train Epoch: 42 [0/196000 (0%)] Ternary accuracy: 67% | Relations accuracy: 75% | Non-relations accuracy: 100%
# Train Epoch: 42 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 78% | Non-relations accuracy: 95%
# Train Epoch: 42 [76800/196000 (39%)] Ternary accuracy: 58% | Relations accuracy: 91% | Non-relations accuracy: 98%
# Train Epoch: 42 [115200/196000 (59%)] Ternary accuracy: 72% | Relations accuracy: 70% | Non-relations accuracy: 100%
# Train Epoch: 42 [153600/196000 (78%)] Ternary accuracy: 58% | Relations accuracy: 75% | Non-relations accuracy: 100%
# Train Epoch: 42 [192000/196000 (98%)] Ternary accuracy: 61% | Relations accuracy: 83% | Non-relations accuracy: 98%
#
#  Test set: Ternary accuracy: 60% Binary accuracy: 84% | Unary accuracy: 100%
#
# Train Epoch: 43 [0/196000 (0%)] Ternary accuracy: 61% | Relations accuracy: 83% | Non-relations accuracy: 100%
# Train Epoch: 43 [38400/196000 (20%)] Ternary accuracy: 58% | Relations accuracy: 75% | Non-relations accuracy: 98%
# Train Epoch: 43 [76800/196000 (39%)] Ternary accuracy: 58% | Relations accuracy: 77% | Non-relations accuracy: 100%
# Train Epoch: 43 [115200/196000 (59%)] Ternary accuracy: 69% | Relations accuracy: 84% | Non-relations accuracy: 100%
# Train Epoch: 43 [153600/196000 (78%)] Ternary accuracy: 58% | Relations accuracy: 77% | Non-relations accuracy: 98%
# Train Epoch: 43 [192000/196000 (98%)] Ternary accuracy: 64% | Relations accuracy: 84% | Non-relations accuracy: 98%
#
#  Test set: Ternary accuracy: 62% Binary accuracy: 86% | Unary accuracy: 100%
#
# Train Epoch: 44 [0/196000 (0%)] Ternary accuracy: 77% | Relations accuracy: 97% | Non-relations accuracy: 100%
# Train Epoch: 44 [38400/196000 (20%)] Ternary accuracy: 62% | Relations accuracy: 86% | Non-relations accuracy: 98%
# Train Epoch: 44 [76800/196000 (39%)] Ternary accuracy: 62% | Relations accuracy: 88% | Non-relations accuracy: 100%
# Train Epoch: 44 [115200/196000 (59%)] Ternary accuracy: 72% | Relations accuracy: 89% | Non-relations accuracy: 100%
# Train Epoch: 44 [153600/196000 (78%)] Ternary accuracy: 64% | Relations accuracy: 88% | Non-relations accuracy: 98%
# Train Epoch: 44 [192000/196000 (98%)] Ternary accuracy: 50% | Relations accuracy: 91% | Non-relations accuracy: 97%
#
#  Test set: Ternary accuracy: 60% Binary accuracy: 86% | Unary accuracy: 99%
#
# Train Epoch: 45 [0/196000 (0%)] Ternary accuracy: 69% | Relations accuracy: 84% | Non-relations accuracy: 98%
# Train Epoch: 45 [38400/196000 (20%)] Ternary accuracy: 62% | Relations accuracy: 77% | Non-relations accuracy: 100%
# Train Epoch: 45 [76800/196000 (39%)] Ternary accuracy: 73% | Relations accuracy: 83% | Non-relations accuracy: 100%
# Train Epoch: 45 [115200/196000 (59%)] Ternary accuracy: 66% | Relations accuracy: 88% | Non-relations accuracy: 98%
# Train Epoch: 45 [153600/196000 (78%)] Ternary accuracy: 69% | Relations accuracy: 83% | Non-relations accuracy: 100%
# Train Epoch: 45 [192000/196000 (98%)] Ternary accuracy: 62% | Relations accuracy: 92% | Non-relations accuracy: 98%
#
#  Test set: Ternary accuracy: 60% Binary accuracy: 86% | Unary accuracy: 99%
#
# Train Epoch: 46 [0/196000 (0%)] Ternary accuracy: 67% | Relations accuracy: 92% | Non-relations accuracy: 98%
# Train Epoch: 46 [38400/196000 (20%)] Ternary accuracy: 64% | Relations accuracy: 86% | Non-relations accuracy: 98%
# Train Epoch: 46 [76800/196000 (39%)] Ternary accuracy: 69% | Relations accuracy: 92% | Non-relations accuracy: 100%
# Train Epoch: 46 [115200/196000 (59%)] Ternary accuracy: 62% | Relations accuracy: 78% | Non-relations accuracy: 100%
# Train Epoch: 46 [153600/196000 (78%)] Ternary accuracy: 66% | Relations accuracy: 86% | Non-relations accuracy: 100%
# Train Epoch: 46 [192000/196000 (98%)] Ternary accuracy: 58% | Relations accuracy: 80% | Non-relations accuracy: 98%
#
#  Test set: Ternary accuracy: 61% Binary accuracy: 87% | Unary accuracy: 99%
#
# Train Epoch: 47 [0/196000 (0%)] Ternary accuracy: 67% | Relations accuracy: 88% | Non-relations accuracy: 100%
# Train Epoch: 47 [38400/196000 (20%)] Ternary accuracy: 67% | Relations accuracy: 86% | Non-relations accuracy: 100%
# Train Epoch: 47 [76800/196000 (39%)] Ternary accuracy: 64% | Relations accuracy: 89% | Non-relations accuracy: 100%
# Train Epoch: 47 [115200/196000 (59%)] Ternary accuracy: 64% | Relations accuracy: 95% | Non-relations accuracy: 100%
# Train Epoch: 47 [153600/196000 (78%)] Ternary accuracy: 67% | Relations accuracy: 88% | Non-relations accuracy: 100%
# Train Epoch: 47 [192000/196000 (98%)] Ternary accuracy: 55% | Relations accuracy: 84% | Non-relations accuracy: 98%
#
#  Test set: Ternary accuracy: 62% Binary accuracy: 89% | Unary accuracy: 100%
#
# Train Epoch: 48 [0/196000 (0%)] Ternary accuracy: 52% | Relations accuracy: 91% | Non-relations accuracy: 98%
# Train Epoch: 48 [38400/196000 (20%)] Ternary accuracy: 69% | Relations accuracy: 91% | Non-relations accuracy: 98%
# Train Epoch: 48 [76800/196000 (39%)] Ternary accuracy: 62% | Relations accuracy: 91% | Non-relations accuracy: 98%
# Train Epoch: 48 [115200/196000 (59%)] Ternary accuracy: 66% | Relations accuracy: 92% | Non-relations accuracy: 100%
# Train Epoch: 48 [153600/196000 (78%)] Ternary accuracy: 70% | Relations accuracy: 95% | Non-relations accuracy: 100%
# Train Epoch: 48 [192000/196000 (98%)] Ternary accuracy: 56% | Relations accuracy: 95% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 63% Binary accuracy: 92% | Unary accuracy: 100%
#
# Train Epoch: 49 [0/196000 (0%)] Ternary accuracy: 77% | Relations accuracy: 89% | Non-relations accuracy: 98%
# Train Epoch: 49 [38400/196000 (20%)] Ternary accuracy: 66% | Relations accuracy: 94% | Non-relations accuracy: 98%
# Train Epoch: 49 [76800/196000 (39%)] Ternary accuracy: 66% | Relations accuracy: 94% | Non-relations accuracy: 100%
# Train Epoch: 49 [115200/196000 (59%)] Ternary accuracy: 64% | Relations accuracy: 92% | Non-relations accuracy: 100%
# Train Epoch: 49 [153600/196000 (78%)] Ternary accuracy: 61% | Relations accuracy: 88% | Non-relations accuracy: 100%
# Train Epoch: 49 [192000/196000 (98%)] Ternary accuracy: 59% | Relations accuracy: 98% | Non-relations accuracy: 98%
#
#  Test set: Ternary accuracy: 64% Binary accuracy: 95% | Unary accuracy: 99%
#
# Train Epoch: 50 [0/196000 (0%)] Ternary accuracy: 70% | Relations accuracy: 100% | Non-relations accuracy: 100%
# Train Epoch: 50 [38400/196000 (20%)] Ternary accuracy: 64% | Relations accuracy: 98% | Non-relations accuracy: 100%
# Train Epoch: 50 [76800/196000 (39%)] Ternary accuracy: 66% | Relations accuracy: 97% | Non-relations accuracy: 100%
# Train Epoch: 50 [115200/196000 (59%)] Ternary accuracy: 70% | Relations accuracy: 97% | Non-relations accuracy: 98%
# Train Epoch: 50 [153600/196000 (78%)] Ternary accuracy: 61% | Relations accuracy: 95% | Non-relations accuracy: 100%
# Train Epoch: 50 [192000/196000 (98%)] Ternary accuracy: 64% | Relations accuracy: 94% | Non-relations accuracy: 100%
#
#  Test set: Ternary accuracy: 63% Binary accuracy: 93% | Unary accuracy: 98%
